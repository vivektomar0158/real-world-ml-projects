# %% [markdown]
# # Market Segmentation dataset from Kaggle for Unsupervised Learning

# %% [markdown]
# ## Link to Dataset- https://www.kaggle.com/datasets/arjunbhasin2013/ccdata

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\vivek\OneDrive\Desktop\Dox\credit_card_segmentation.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.drop('CUST_ID', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# ### Filling Missing values

# %%
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].median(), inplace=True)
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].median(), inplace=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_3076\1917152532.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].median(), inplace=True)
# C:\Users\vivek\AppData\Local\Temp\ipykernel_3076\1917152532.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (8950, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# ### Checking Distribution for skewed features

# %%
df.var()
# Out:
# BALANCE                             4.332775e+06
# BALANCE_FREQUENCY                   5.612351e-02
# PURCHASES                           4.565208e+06
# ONEOFF_PURCHASES                    2.755228e+06
# INSTALLMENTS_PURCHASES              8.178274e+05
# CASH_ADVANCE                        4.398096e+06
# PURCHASES_FREQUENCY                 1.610985e-01
# ONEOFF_PURCHASES_FREQUENCY          8.900441e-02
# PURCHASES_INSTALLMENTS_FREQUENCY    1.579647e-01
# CASH_ADVANCE_FREQUENCY              4.004857e-02
# CASH_ADVANCE_TRX                    4.657580e+01
# PURCHASES_TRX                       6.179027e+02
# CREDIT_LIMIT                        1.323975e+07
# PAYMENTS                            8.381394e+06
# MINIMUM_PAYMENTS                    5.441920e+06
# PRC_FULL_PAYMENT                    8.555578e-02
# TENURE                              1.791129e+00
# dtype: float64

# %%
for col in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    
    # Plot histogram
    plt.hist(df[col].dropna(), bins=30, edgecolor='black', alpha=0.7)

    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
df.skew().sort_values()
# Out:
# TENURE                              -2.943017
# BALANCE_FREQUENCY                   -2.023266
# PURCHASES_FREQUENCY                  0.060164
# PURCHASES_INSTALLMENTS_FREQUENCY     0.509201
# CREDIT_LIMIT                         1.522636
# ONEOFF_PURCHASES_FREQUENCY           1.535613
# CASH_ADVANCE_FREQUENCY               1.828686
# PRC_FULL_PAYMENT                     1.942820
# BALANCE                              2.393386
# PURCHASES_TRX                        4.630655
# CASH_ADVANCE                         5.166609
# CASH_ADVANCE_TRX                     5.721298
# PAYMENTS                             5.907620
# INSTALLMENTS_PURCHASES               7.299120
# PURCHASES                            8.144269
# ONEOFF_PURCHASES                    10.045083
# MINIMUM_PAYMENTS                    13.852446
# dtype: float64

# %% [markdown]
# ## Fixing the skewed columns

# %%
from sklearn.preprocessing import QuantileTransformer
from scipy.stats import skew

num_cols = df.select_dtypes(include='number').columns

skew_vals = df[num_cols].apply(skew)
skewed_cols = skew_vals[abs(skew_vals) > 1].index

qt = QuantileTransformer(output_distribution='normal', random_state=42)

for col in skewed_cols:
    df[[col]] = qt.fit_transform(df[[col]])
    print(f"Fixed skew in: {col}")
# Out:
# Fixed skew in: BALANCE
# Fixed skew in: BALANCE_FREQUENCY
# Fixed skew in: PURCHASES
# Fixed skew in: ONEOFF_PURCHASES
# Fixed skew in: INSTALLMENTS_PURCHASES
# Fixed skew in: CASH_ADVANCE
# Fixed skew in: ONEOFF_PURCHASES_FREQUENCY
# Fixed skew in: CASH_ADVANCE_FREQUENCY
# Fixed skew in: CASH_ADVANCE_TRX
# Fixed skew in: PURCHASES_TRX
# Fixed skew in: CREDIT_LIMIT
# Fixed skew in: PAYMENTS
# Fixed skew in: MINIMUM_PAYMENTS
# Fixed skew in: PRC_FULL_PAYMENT
# Fixed skew in: TENURE

# %%
df.std().sort_values()
# Out:
# PURCHASES_INSTALLMENTS_FREQUENCY    0.397448
# PURCHASES_FREQUENCY                 0.401371
# CREDIT_LIMIT                        0.995822
# MINIMUM_PAYMENTS                    1.002808
# BALANCE                             1.084729
# PAYMENTS                            1.254523
# PURCHASES_TRX                       2.436938
# PURCHASES                           2.437132
# TENURE                              2.632740
# INSTALLMENTS_PURCHASES              2.965254
# BALANCE_FREQUENCY                   2.992257
# ONEOFF_PURCHASES                    3.014242
# CASH_ADVANCE_FREQUENCY              3.038547
# CASH_ADVANCE                        3.039285
# CASH_ADVANCE_TRX                    3.040103
# ONEOFF_PURCHASES_FREQUENCY          3.314988
# PRC_FULL_PAYMENT                    3.348817
# dtype: float64

# %%
# Plot boxplot for all numeric columns
for col in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(df[col], vert=False)
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Applying Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_data = scaler.fit_transform(df.select_dtypes(include='number'))

df_scaled = pd.DataFrame(scaled_data, columns=df.select_dtypes(include='number').columns)

# %%
print(df_scaled.mean().round(2))
print(df_scaled.std().round(2))
# Out:
# BALANCE                             0.0
# BALANCE_FREQUENCY                  -0.0
# PURCHASES                          -0.0
# ONEOFF_PURCHASES                    0.0
# INSTALLMENTS_PURCHASES              0.0
# CASH_ADVANCE                       -0.0
# PURCHASES_FREQUENCY                 0.0
# ONEOFF_PURCHASES_FREQUENCY         -0.0
# PURCHASES_INSTALLMENTS_FREQUENCY    0.0
# CASH_ADVANCE_FREQUENCY             -0.0
# CASH_ADVANCE_TRX                    0.0
# PURCHASES_TRX                       0.0
# CREDIT_LIMIT                       -0.0
# PAYMENTS                            0.0
# MINIMUM_PAYMENTS                    0.0
# PRC_FULL_PAYMENT                    0.0
# TENURE                             -0.0
# dtype: float64
# BALANCE                             1.0
# BALANCE_FREQUENCY                   1.0
# PURCHASES                           1.0
# ONEOFF_PURCHASES                    1.0
# INSTALLMENTS_PURCHASES              1.0
# CASH_ADVANCE                        1.0
# ...

# %% [markdown]
# ### Using elbow method to find Clusters

# %%
from sklearn.cluster import KMeans

inertia = []
k_range = range(1,11)

for k in k_range: 
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,4))
plt.plot(k_range, inertia, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (WCSS)')
plt.title('Elbow Method For Optimal k')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Applying Kmeans

# %%
kmeans = KMeans(n_clusters=4, random_state=42, n_init='auto')
kmeans.fit(df_scaled)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df['Cluster'] = kmeans.labels_ 
df['Cluster'].value_counts()
# Out:
# Cluster
# 2    2812
# 0    2245
# 3    2046
# 1    1847
# Name: count, dtype: int64

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(df_scaled)

pca_df = pd.DataFrame(data=pca_data, columns=['PCA1', 'PCA2'])
pca_df['Cluster'] = df['Cluster']

# %% [markdown]
# ### Finding Segmentation

# %%
#visualising 
for cluster in sorted(pca_df['Cluster'].unique()):
    cluster_data = pca_df[pca_df['Cluster'] == cluster]
    plt.scatter(cluster_data['PCA1'], cluster_data['PCA2'], label=f'Cluster {cluster}', s=30)

plt.title('Customer Segmentation (PCA Projection)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Group by cluster
cluster_profiles = df.groupby('Cluster').mean(numeric_only=True)
cluster_profiles
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0        0.615902           4.127706   0.377550         -0.425797
# 1       -0.989245           2.088228   0.012349         -5.112756
# 2       -0.192311           3.229391   0.654245          0.796109
# 3        0.384156           3.299047  -5.194949         -5.199338
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                     -1.410490      0.835402             0.573380
# 1                      0.542126     -5.103402             0.708826
# 2                     -1.440393     -5.197439             0.637132
# 3                     -5.189403      0.817032             0.000285
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                         -0.290481                          0.398654
# 1                         -5.110466                          0.673687
# ...

# %%
# Group by cluster
numeric_cols = df.select_dtypes(include='number').columns.drop('Cluster')

cluster_profiles = df.groupby('Cluster')[numeric_cols].mean()

print(cluster_profiles)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0        0.615902           4.127706   0.377550         -0.425797
# 1       -0.989245           2.088228   0.012349         -5.112756
# 2       -0.192311           3.229391   0.654245          0.796109
# 3        0.384156           3.299047  -5.194949         -5.199338
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                     -1.410490      0.835402             0.573380
# 1                      0.542126     -5.103402             0.708826
# 2                     -1.440393     -5.197439             0.637132
# 3                     -5.189403      0.817032             0.000285
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                         -0.290481                          0.398654
# 1                         -5.110466                          0.673687
# ...

# %% [markdown]
# ## Each cluster Average Values

# %%
top_features = ['BALANCE', 'PURCHASES', 'PAYMENTS', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES']

# Plot
cluster_profiles[top_features].T.plot(kind='bar', figsize=(10, 6))
plt.title("Average Feature Values by Cluster")
plt.xlabel("Features")
plt.ylabel("Average Value")
plt.legend(title="Cluster")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving as CSV

# %%
df.to_csv("credit_card_clustered_customers.csv", index=False)

# %% [markdown]
# # Conclusion

# %% [markdown]
# I worked on a credit card customer segmentation project using unsupervised learning, with the goal of identifying distinct customer groups based on their transaction behavior. The dataset was sourced from Kaggle and included features like balance, purchases, payments, and spending styles.
#
# To begin, I handled missing values in the MINIMUM_PAYMENTS and CREDIT_LIMIT columns using the median, since it's less sensitive to outliers compared to the mean. I then moved on to exploratory data analysis (EDA), where I visualized feature distributions, checked for skewness, and used boxplots to detect outliers.
#
# Some features like PURCHASES and MINIMUM_PAYMENTS were highly skewed, so I applied log transformation (np.log1p) to make them more normally distributed. Outliers were identified using the IQR method, and since they weren’t overly dominant (i.e., not more than 10–15%), I chose to retain them in the data.
#
# Next, I standardized the data using StandardScaler, which ensures all features contribute equally during clustering. I then used the Elbow Method to determine the optimal number of clusters. The curve clearly bent at k = 4, so I applied K-Means clustering with 4 clusters and added those labels back into the dataset.
#
# For visualization, I used PCA (Principal Component Analysis) to reduce the feature space to 2 dimensions. The resulting 2D scatter plot showed well-separated clusters, confirming the effectiveness of the segmentation.
#
# To understand what each cluster represents, I analyzed the average feature values across clusters. Here’s a summary:
#
# 🔵 Cluster 0: Moderate balance and purchases — typical average users
#
# 🟠 Cluster 1: Low balance, low spending — possibly dormant users
#
# 🟢 Cluster 2: High purchases and payments — likely high-value customers
#
# 🔴 Cluster 3: Very low activity — almost inactive or disengaged accounts
#
# This clustering solution can help businesses tailor credit card offerings, reward high-value customers, and re-engage low-activity users. It also provides insights into spending patterns that can guide marketing and customer relationship strategies.
